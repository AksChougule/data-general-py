# %%
import pandas as pd
from matplotlib import *

# %%
df = pd.read_csv('~/datasets/Employment/Employment_Data.csv')

# %%
# Get dimensions
df.shape
# Out:
# (173, 18)

# %%
# Describe the dataframe
df.describe()
# Out:
#              1991        1992        1993        1994        1995        1996  \
# count  173.000000  173.000000  173.000000  173.000000  173.000000  173.000000
# mean    57.837572   57.727168   57.500000   57.644509   57.685549   57.619653
# std     10.805260   10.813493   10.906250   10.770196   10.707489   10.846636
# min     33.500000   34.299999   35.099998   35.000000   35.000000   35.099998
# 25%     51.099998   51.099998   50.500000   50.799999   50.299999   50.700001
# 50%     56.900002   57.299999   56.799999   56.700001   56.599998   56.099998
# 75%     63.200001   63.099998   63.099998   64.099998   63.599998   64.099998
# max     87.500000   87.199997   87.000000   87.699997   87.300003   86.800003
#
#              1997        1998        1999        2000        2001        2002  \
# count  173.000000  173.000000  173.000000  173.000000  173.000000  173.000000
# mean    57.725434   57.774566   57.784971   57.901734   57.941619   57.880347
# ...

# %%
# Get column names
df.columns
# Out:
# Index(['Total above 15 employment to population (%)', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007'],
#       dtype='object')

# %%
# Get data type for each column
df.dtypes
# Out:
# Total above 15 employment to population (%)     object
# 1991                                           float64
# 1992                                           float64
# 1993                                           float64
# 1994                                           float64
# 1995                                           float64
# 1996                                           float64
# 1997                                           float64
# 1998                                           float64
# 1999                                           float64
# 2000                                           float64
# 2001                                           float64
# 2002                                           float64
# 2003                                           float64
# 2004                                           float64
# 2005                                           float64
# 2006                                           float64
# ...

# %%
# Get quick data quality summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 18 columns):
# Total above 15 employment to population (%)    173 non-null object
# 1991                                           173 non-null float64
# 1992                                           173 non-null float64
# 1993                                           173 non-null float64
# 1994                                           173 non-null float64
# 1995                                           173 non-null float64
# 1996                                           173 non-null float64
# 1997                                           173 non-null float64
# 1998                                           173 non-null float64
# 1999                                           173 non-null float64
# 2000                                           173 non-null float64
# 2001                                           173 non-null float64
# ...

# %%
# First 5 rows
df[:5]
# or
# df[1:5,]
# Out:
#   Total above 15 employment to population (%)       1991       1992  \
# 0                                 Afghanistan  56.700001  56.500000
# 1                                     Albania  52.700001  52.299999
# 2                                     Algeria  39.400002  38.900002
# 3                                      Angola  75.800003  75.800003
# 4                                   Argentina  53.599998  53.799999
#
#         1993       1994       1995       1996       1997       1998  \
# 0  56.599998  56.200001  56.200001  56.099998  56.200001  56.200001
# 1  52.400002  52.700001  52.799999  52.599998  52.400002  52.099998
# 2  39.400002  39.400002  38.099998  38.900002  39.700001  39.500000
# 3  75.500000  75.900002  75.800003  75.900002  75.699997  75.599998
# 4  53.700001  53.799999  53.500000  54.400002  54.900002  55.000000
#
#         1999       2000       2001       2002       2003       2004  \
# 0  56.099998  56.099998  56.500000  56.400002  54.400002  56.000000
# ...

# %%
# First 4 columns, then take head
df.iloc[:,0:4].head()
# Out:
#   Total above 15 employment to population (%)       1991       1992       1993
# 0                                 Afghanistan  56.700001  56.500000  56.599998
# 1                                     Albania  52.700001  52.299999  52.400002
# 2                                     Algeria  39.400002  38.900002  39.400002
# 3                                      Angola  75.800003  75.800003  75.500000
# 4                                   Argentina  53.599998  53.799999  53.700001

# %%
# Subset by index
df.iloc[0:3,0:4]
# Out:
#   Total above 15 employment to population (%)       1991       1992       1993
# 0                                 Afghanistan  56.700001  56.500000  56.599998
# 1                                     Albania  52.700001  52.299999  52.400002
# 2                                     Algeria  39.400002  38.900002  39.400002

# %%
# Subset by col names and rows
df.loc[0:3,['1991','1993']]
# Out:
#         1991       1993
# 0  56.700001  56.599998
# 1  52.700001  52.400002
# 2  39.400002  39.400002
# 3  75.800003  75.500000

# %%
# Subset by column names then use head
df[['1991','1992']].head()
# Out:
#         1991       1992
# 0  56.700001  56.500000
# 1  52.700001  52.299999
# 2  39.400002  38.900002
# 3  75.800003  75.800003
# 4  53.599998  53.799999

# %%
# Select 2nd last row
df.iloc[-2,]
# Out:
# Total above 15 employment to population (%)    Uzbekistan
# 1991                                                 54.5
# 1992                                                 53.3
# 1993                                                 52.9
# 1994                                                 52.4
# 1995                                                 52.2
# 1996                                                 52.5
# 1997                                                 53.1
# 1998                                                 53.6
# 1999                                                 53.9
# 2000                                                 54.2
# 2001                                                 54.5
# 2002                                                 54.7
# 2003                                                   55
# 2004                                                 55.7
# 2005                                                 56.1
# ...

# %%
# Select 2nd row
df.loc[2]
# Out:
# Total above 15 employment to population (%)    Algeria
# 1991                                              39.4
# 1992                                              38.9
# 1993                                              39.4
# 1994                                              39.4
# 1995                                              38.1
# 1996                                              38.9
# 1997                                              39.7
# 1998                                              39.5
# 1999                                              39.4
# 2000                                              38.6
# 2001                                              40.4
# 2002                                              41.5
# 2003                                              42.8
# 2004                                              46.4
# 2005                                                48
# 2006                                                50
# ...

# %%
display_range = list(range(3,6))
display_range
# Out:
# [3, 4, 5]

# %%
# Using external var to subset
df.iloc[:,display_range].head()
# Out:
#         1993       1994       1995
# 0  56.599998  56.200001  56.200001
# 1  52.400002  52.700001  52.799999
# 2  39.400002  39.400002  38.099998
# 3  75.500000  75.900002  75.800003
# 4  53.700001  53.799999  53.500000

# %% [markdown]
# #### Column Name Change

# %%
df.columns[0]
# Out:
# 'Total above 15 employment to population (%)'

# %%
df.columns.values[0] = 'country_name'

# %%
df.columns[0]
# Out:
# 'country_name'

# %%
# Transpose
df_t=df.set_index('country_name').T.rename_axis('Year').rename_axis(None, 1)
#df_t=df.columns('country_name').T.rename_axis('Year').rename_axis(None, 1)

# %%
# Check the transposed dataframe
df_t.iloc[0:5,0:6]
# Out:
#       Afghanistan    Albania    Algeria     Angola  Argentina    Armenia
# Year
# 1991    56.700001  52.700001  39.400002  75.800003  53.599998  39.299999
# 1992    56.500000  52.299999  38.900002  75.800003  53.799999  38.200001
# 1993    56.599998  52.400002  39.400002  75.500000  53.700001  37.400002
# 1994    56.200001  52.700001  39.400002  75.900002  53.799999  37.400002
# 1995    56.200001  52.799999  38.099998  75.800003  53.500000  37.099998

# %%
# Add the index (Year) as a column in the df
df_t['Year'] = df_t.index
# df_t.columns.values[0]='Year'
df_t.columns
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina', 'Armenia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        ...
#        'Turkmenistan', 'Uganda', 'Ukraine', 'United Arab Emirates',
#        'United Kingdom', 'United States', 'Uruguay', 'Uzbekistan', 'Venezuela',
#        'Year'],
#       dtype='object', length=174)

# %%
df_t.iloc[:,0:5].head(5)
# Out:
#       Afghanistan    Albania    Algeria     Angola  Argentina
# Year
# 1991    56.700001  52.700001  39.400002  75.800003  53.599998
# 1992    56.500000  52.299999  38.900002  75.800003  53.799999
# 1993    56.599998  52.400002  39.400002  75.500000  53.700001
# 1994    56.200001  52.700001  39.400002  75.900002  53.799999
# 1995    56.200001  52.799999  38.099998  75.800003  53.500000

# %%
df.head()
# Out:
#   country_name       1991       1992       1993       1994       1995  \
# 0  Afghanistan  56.700001  56.500000  56.599998  56.200001  56.200001
# 1      Albania  52.700001  52.299999  52.400002  52.700001  52.799999
# 2      Algeria  39.400002  38.900002  39.400002  39.400002  38.099998
# 3       Angola  75.800003  75.800003  75.500000  75.900002  75.800003
# 4    Argentina  53.599998  53.799999  53.700001  53.799999  53.500000
#
#         1996       1997       1998       1999       2000       2001  \
# 0  56.099998  56.200001  56.200001  56.099998  56.099998  56.500000
# 1  52.599998  52.400002  52.099998  52.099998  51.900002  51.799999
# 2  38.900002  39.700001  39.500000  39.400002  38.599998  40.400002
# 3  75.900002  75.699997  75.599998  75.599998  75.500000  75.500000
# 4  54.400002  54.900002  55.000000  54.900002  55.500000  55.599998
#
#         2002       2003       2004       2005       2006       2007
# ...

# %%
df_backup=df

# %% [markdown]
# Let's add a new column to check the decade (if the Year is in 1990s or 2000s)

# %%
# To get the value from 1990s from the column Year
df_t[df_t['Year'].str.contains("199")]
# Out:
#       Afghanistan    Albania    Algeria     Angola  Argentina    Armenia  \
# Year
# 1991    56.700001  52.700001  39.400002  75.800003  53.599998  39.299999
# 1992    56.500000  52.299999  38.900002  75.800003  53.799999  38.200001
# 1993    56.599998  52.400002  39.400002  75.500000  53.700001  37.400002
# 1994    56.200001  52.700001  39.400002  75.900002  53.799999  37.400002
# 1995    56.200001  52.799999  38.099998  75.800003  53.500000  37.099998
# 1996    56.099998  52.599998  38.900002  75.900002  54.400002  38.099998
# 1997    56.200001  52.400002  39.700001  75.699997  54.900002  37.400002
# 1998    56.200001  52.099998  39.500000  75.599998  55.000000  38.099998
# 1999    56.099998  52.099998  39.400002  75.599998  54.900002  37.200001
#
#       Australia    Austria  Azerbaijan    Bahamas  ...   Turkmenistan  \
# Year                                               ...
# 1991  57.200001  54.200001   56.900002  63.000000  ...      56.099998
# ...

# %%
# Should change the location to 0 if we want this to be the first column
df_t.insert(column='Decade',loc=1,value='NA')

# %%
df_t.iloc[:,0:5].head(5)
# Out:
#       Afghanistan Decade    Albania    Algeria     Angola
# Year
# 1991    56.700001     NA  52.700001  39.400002  75.800003
# 1992    56.500000     NA  52.299999  38.900002  75.800003
# 1993    56.599998     NA  52.400002  39.400002  75.500000
# 1994    56.200001     NA  52.700001  39.400002  75.900002
# 1995    56.200001     NA  52.799999  38.099998  75.800003

# %%
df_t.loc[df_t['Year'].str.contains("199"),'Decade'] = '1990s'

# %%
df_t.loc[df_t['Year'].str.contains("199"),'Decade']
# Out:
# Year
# 1991    1990s
# 1992    1990s
# 1993    1990s
# 1994    1990s
# 1995    1990s
# 1996    1990s
# 1997    1990s
# 1998    1990s
# 1999    1990s
# Name: Decade, dtype: object

# %%
df_t.loc[df_t['Year'].str.contains("200"),'Decade'] = '2000s'

# %%
df_t['Decade']
# Out:
# Year
# 1991    1990s
# 1992    1990s
# 1993    1990s
# 1994    1990s
# 1995    1990s
# 1996    1990s
# 1997    1990s
# 1998    1990s
# 1999    1990s
# 2000    2000s
# 2001    2000s
# 2002    2000s
# 2003    2000s
# 2004    2000s
# 2005    2000s
# 2006    2000s
# 2007    2000s
# Name: Decade, dtype: object

# %%
# Group by Decade and mean of all columns
df_t.groupby('Decade').mean()
# Out:
#         Afghanistan    Albania   Algeria     Angola  Argentina  Armenia  \
# Decade
# 1990s     56.311111  52.455555  39.18889  75.733334  54.177778  37.8000
# 2000s     55.637500  51.662500  44.77500  75.549999  57.050000  39.1375
#
#         Australia    Austria  Azerbaijan    Bahamas    ...       Turkey  \
# Decade                                                 ...
# 1990s   57.522223  55.566667   56.444444  64.099999    ...      50.5000
# 2000s   60.300000  56.437500   58.612501  65.937500    ...      44.4375
#
#         Turkmenistan     Uganda    Ukraine  United Arab Emirates  \
# Decade
# 1990s      56.788889  84.211111  57.155555             72.677778
# 2000s      58.862500  83.424998  52.312500             75.125000
#
#         United Kingdom  United States  Uruguay  Uzbekistan  Venezuela
# Decade
# 1990s        57.000000      62.522222  55.3000   53.155556  53.044444
# 2000s        59.212501      62.562499  56.6625   55.525000  55.962500
#
# [2 rows x 173 columns]

# %%
# Group by Decade and mean of single column
df_t.groupby('Decade')['India'].mean()
# Out:
# Decade
# 1990s    58.522222
# 2000s    56.375000
# Name: India, dtype: float64

# %% [markdown]
# Similarly we can run groupby function on multiple columns:<br>
# **e.g. df_t.groupby(['Decade','Quarter'])[['India','China']].mean()**

# %%
df_t[['Year','India']].plot(title="India Employment % over the years")

# %%
df_t[['Year','India','China']].plot(title="India and China Employment % over the years",x='Year')

# %%
# Get tables (HTML) from a url
url_data = pd.read_html("http://www.geonames.org/countries/",header=0)

# %%
url_data[1].head(5)
# Out:
#   ISO-3166alpha2 ISO-3166alpha3  ISO-3166numeric fips               Country  \
# 0             AD            AND               20   AN               Andorra
# 1             AE            ARE              784   AE  United Arab Emirates
# 2             AF            AFG                4   AF           Afghanistan
# 3             AG            ATG               28   AC   Antigua and Barbuda
# 4             AI            AIA              660   AV              Anguilla
#
#             Capital  Area in km²  Population Continent
# 0  Andorra la Vella        468.0       84000        EU
# 1         Abu Dhabi      82880.0     4975593        AS
# 2             Kabul     647500.0    29121286        AS
# 3        St. John's        443.0       86754       NaN
# 4        The Valley        102.0       13254       NaN

# %%
continent_data = url_data[1]

# %%
continent_data.columns.values
# Out:
# array(['ISO-3166alpha2', 'ISO-3166alpha3', 'ISO-3166numeric', 'fips',
#        'Country', 'Capital', 'Area in km²', 'Population', 'Continent'],
#       dtype=object)

# %%
type(continent_data)
# Out:
# pandas.core.frame.DataFrame

# %%
continent_data.iloc[:,4].head()
# Out:
# 0                 Andorra
# 1    United Arab Emirates
# 2             Afghanistan
# 3     Antigua and Barbuda
# 4                Anguilla
# Name: Country, dtype: object

# %%
#continent_data.columns=continent_data.iloc[0,]

# %%
continent_data.columns
# Out:
# Index(['ISO-3166alpha2', 'ISO-3166alpha3', 'ISO-3166numeric', 'fips',
#        'Country', 'Capital', 'Area in km²', 'Population', 'Continent'],
#       dtype='object')

# %%
continent_data.head()
# Out:
#   ISO-3166alpha2 ISO-3166alpha3  ISO-3166numeric fips               Country  \
# 0             AD            AND               20   AN               Andorra
# 1             AE            ARE              784   AE  United Arab Emirates
# 2             AF            AFG                4   AF           Afghanistan
# 3             AG            ATG               28   AC   Antigua and Barbuda
# 4             AI            AIA              660   AV              Anguilla
#
#             Capital  Area in km²  Population Continent
# 0  Andorra la Vella        468.0       84000        EU
# 1         Abu Dhabi      82880.0     4975593        AS
# 2             Kabul     647500.0    29121286        AS
# 3        St. John's        443.0       86754       NaN
# 4        The Valley        102.0       13254       NaN

# %%
# Delete first row by referring to the index (as we have added that as column names)
#continent_data = continent_data.drop(0)

# %%
continent_data_subset = continent_data[['Country','Continent']]

# %%
continent_data_subset.head()
# Out:
#                 Country Continent
# 0               Andorra        EU
# 1  United Arab Emirates        AS
# 2           Afghanistan        AS
# 3   Antigua and Barbuda       NaN
# 4              Anguilla       NaN

# %%
df.head()
# Out:
#   country_name       1991       1992       1993       1994       1995  \
# 0  Afghanistan  56.700001  56.500000  56.599998  56.200001  56.200001
# 1      Albania  52.700001  52.299999  52.400002  52.700001  52.799999
# 2      Algeria  39.400002  38.900002  39.400002  39.400002  38.099998
# 3       Angola  75.800003  75.800003  75.500000  75.900002  75.800003
# 4    Argentina  53.599998  53.799999  53.700001  53.799999  53.500000
#
#         1996       1997       1998       1999       2000       2001  \
# 0  56.099998  56.200001  56.200001  56.099998  56.099998  56.500000
# 1  52.599998  52.400002  52.099998  52.099998  51.900002  51.799999
# 2  38.900002  39.700001  39.500000  39.400002  38.599998  40.400002
# 3  75.900002  75.699997  75.599998  75.599998  75.500000  75.500000
# 4  54.400002  54.900002  55.000000  54.900002  55.500000  55.599998
#
#         2002       2003       2004       2005       2006       2007
# ...

# %%
df.columns
# Out:
# Index(['country_name', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007'],
#       dtype='object')

# %%
# Unfortunately we have to use the original column name for the merge operation
# So instead of 'country_name' we use 'Total above 15 employment to population (%)'
master_set=pd.merge(df,continent_data_subset,how='inner',left_on='Total above 15 employment to population (%)',right_on='Country')

# %%
master_set.dtypes
# Out:
# country_name     object
# 1991            float64
# 1992            float64
# 1993            float64
# 1994            float64
# 1995            float64
# 1996            float64
# 1997            float64
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# Country          object
# Continent        object
# dtype: object

# %%
master_set.head(7)
# Out:
#   country_name       1991       1992       1993       1994       1995  \
# 0  Afghanistan  56.700001  56.500000  56.599998  56.200001  56.200001
# 1      Albania  52.700001  52.299999  52.400002  52.700001  52.799999
# 2      Algeria  39.400002  38.900002  39.400002  39.400002  38.099998
# 3       Angola  75.800003  75.800003  75.500000  75.900002  75.800003
# 4    Argentina  53.599998  53.799999  53.700001  53.799999  53.500000
# 5      Armenia  39.299999  38.200001  37.400002  37.400002  37.099998
# 6    Australia  57.200001  56.200001  55.900002  56.900002  58.400002
#
#         1996       1997       1998       1999       2000       2001  \
# 0  56.099998  56.200001  56.200001  56.099998  56.099998  56.500000
# 1  52.599998  52.400002  52.099998  52.099998  51.900002  51.799999
# 2  38.900002  39.700001  39.500000  39.400002  38.599998  40.400002
# 3  75.900002  75.699997  75.599998  75.599998  75.500000  75.500000
# ...

# %% [raw]
# Let's check how many rows (countries) we lost due to the inner join

# %%
len(df)
# Out:
# 173

# %%
len(master_set)
# Out:
# 158
